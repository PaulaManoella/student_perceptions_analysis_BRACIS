# %%
import pandas as pd

# %%
bertopic_new = pd.read_pickle('../src/tmp/df_bertopic_topics.pkl')
bertopic_new
# Out:
#                                              keywords  \
# 0   [conteudo, prova, didatica, sala, alem, tempo,...
# 1   [excelente, bem, didatica, boa, otimo, assunto...
# 2   [avaliacao, provas, metodo, avaliacoes, poderi...
# 3   [atencioso, solicita, humilde, esforcado, para...
# 4   [comentarios, nada, xxxxxxxxxxxx, consta, come...
# 5   [disciplinas, alguns, bom, apesar, greve, prov...
# 6   [profissional, impecaveis, qualifiquado, ok, d...
# 7   [comentarios, sexo, desnecessarios, outra, sex...
# 8   [portugues, apresentou, influenciou, versa, vi...
# 9   [explica, dia, assunto, clara, especifico, com...
# 10  [novas, tecnologias, conhece, ministra, bastan...
# 11  [acelerado, ritmo, rapido, demais, extenso, ac...
# 12  [prof, profisional, sensacional, extraordinari...
# 13  [pegadinhas, faltou, rei, aderiu, pequena, con...
#
#                                                  docs
# 0   [professor ausente totalmente antiprofissional...
# ...

# %%
bertopic_new.to_excel('bertopic_topics.xlsx')
